# %% [markdown]
# #### 01/2018
#
#
# Few things as seductive or exciting as an insecure woman??
#
# Fortune cookie 🥠
#
# January 24, 2018
#
# A solid challenge will bring forth your finest abilities {cite}`holdgraf_portable_2017`.
