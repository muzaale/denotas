# %% [markdown]
# # todo
#
# ## 07/26/2023
#
# 1. grants: topics, needs
#     - outcomes: hospitalization, esrd, death in older living kidney donors (k08: 2020-2024)
#     - exposures: natural language processing to extract frailty from clinical notes of older living kidney donors (r21: 2024-2025)
#     - predictors: risk calculators in older living kidney donors (k08: 2020-2024)
#     - caregivers: communication, education, support with co-pilot plugin (r03: 2024-2025)
#     - mentoring: grant for ai/clinical informatics/epidemiology in older living kidney donors (k24: 2024-2029)
#
# 2. papers:
#     - nhanes public data
#     - automated stata `(jupyter-book)``
#     - then automated r
#     - ultimately automated python
#     - rich documentation
#
# 3. teaching:
#     - stata
#     - r
#     - python
#     - jupyter-book
#     - github
# 4. mentoring
#     - undergraduates
#     - medical students
#     - residents
#     - fellows
#     - junior faculty
#     - collaborators
# 5. service
#     - national
#     - regional
#     - local
#     - institutional
# 6. clinical
#     - kidney transplant
#     - living kidney donor
#     - clinical transplantation
#
# ---

# %% [markdown]
# ## 07/27/2023
#
# 8. clinical transplant review:
#
# In this bibliography analysis, the authors study "Research productivity of the United States of America in the field of organ transplantation."
#
# How these efforts may translate into better clinical care, more refined guidelines, or more effective policies for the care of our patients is not clear.
#
# Nothing seems novel either. It is well known that the USA has the largest volume of patients in the field of transplantation and has led in peer-reviewed output since the 1950s. Ranking transplant centers, researchers, and journals in the USA based on number of citations is something that might be of interest to some, and a need that may be met by magazines such as US News and World Report. But it is not the kind of work that Clinical Transplantation is interested in publishing.
#
# Granted, when we look at the methodological rigor of this paper, we find fundamental flaws. Table 5, for instance, describes the "top-15 cited articles in the field of trnsplantation by authors from the USA." As an author of articles in the field of transplantation, I have published papers in General medical journals with more citations than most of these listed articles and these have not been captured. Which is to say, the denominator of this study is not the most appropriate. The denominator should be the number of articles published in the field of transplantation by authors in any peer-reviewed journal (and from any country!).
#
# But what would be the point of such a study? From an editorial perspective, we are not in the business of counting citations. We are in the business of improving the health of our patients.
#
# ---

# %% [markdown]
# 9. What I wish to share with P:
#
# + Free AI has arrived and will exponentiate speed and quality of output for the student, graduate, and working professional.
# + You probably don't need to learn how to code statistical programs such as SPSS. You need to learn how to use AI.
# + As your thesis takes shape, you will need to learn how to use AI to analyze your data and write your thesis
# + I know you'll be served if you do all the above incrementally, as you go along, rather than in a big bang at the end
#
# ---

# %% [markdown]
# 10. Hello Abimereki Muzaale,
#
# Congratulations, your application has been approved! Next, you need to upload a copy of your itemized invoice showing all tuition and fees. To retrieve your statement, you will need to log into your SIS account and select Billing, click Summary, and under View Statement select the statement you need. This will then be reviewed and approved by EdAssist. Visit https://hr.jhu.edu/benefits-worklife/tuition-assistance/tuition-reimbursement/degree-seeking-credit-courses/ for step-by-step instructions.
#
# NOTE: The amount approved on your application is subject to change upon review of your itemized invoice/statement. If you have reached your annual cap limit during application review for payment processing, your application will be paid out up to the cap limit and you will be responsible for any amounts that have exceeded your annual cap limit. If you have received any gift aid (scholarships/grants/discounts/etc.), your approved amount will be reduced at the time of payment processing.
#
# Application: 11188178
# Program: Tuition Remission at JHU
# Session: 08/28/2023 - 10/24/2023
# Course Name(s): Thesis research clinical investigation
#
# You can create, edit, and manage your applications via the website.
#
# If you have questions regarding your application, please use the 'Comments' section to communicate with us. For additional assistance, please visit the support page within the site and we will be happy to assist!
#
# Regards,
# Bright Horizons EdAssist Solutions
# Website: https://JHU.edassist.com
#
# This is an automatically generated email. Please do not reply to this address.
#
#
#
#
# EdAssist | 2 Wells Ave. Newton, MA 02459.
# A Bright Horizons Solution at Work.
# www.edassist.com
#
# ---

# %% [markdown]
# Good morning, Kadi; l always celebrate hearing from you. As you know, ours is not a literate culture. But I learned from your late grandfather, with whom you shared the clan name, "Dhatemwa kulala aye dhayawukana emibala." That is, they diverge when it comes to the sound they make and the philosophy of life they articulate. This was especially noteworthy in the case of twins who frequently diverge in their behaviour preferences!
#
# Literally, the name conveys the need to manage your expectations of people accordingly.
#
# "Although drums my have been made from the stem of a the same tree they don't sound the same."
#
#
# Good morning, Kadi! I always celebrate hearing from you. As you know, our culture is not rooted in literacy, but the wisdom of our ancestors has been passed down through generations, including the teachings from your late grandfather, withwhom you shared the clan name, "Dhatemwa kulala aye dhayawukana emibala."
#
# It reminds one of the diversity of people and their perspectives. Just like the "drums cut from the stem of the same tree", each person creates a unique sound and articulates their philosophy of life differently. This understanding becomes especially apparent when dealing with twins, who, despite sharing the same biological origin, often display distinct behavior preferences.
#
# I cherish the wisdom embedded in this saying, and it reminds me to manage my expectations of others with empathy and understanding. By recognizing and appreciating the individuality of each person, I can foster better relationships and create `harmony` within our community.
#
# --
#
# Thanks, daddy! I like this! I will use it thematically for my next project. I incorporate the elements in "Dhatemwa kulala aye dhayawukana emibal" to describe github repositories and projects. I will use the following:
#
# abimereki@gmail.com
# dhatemwakulala@gmail.com
# github.com/dhatemwakulala
# engoma
# dhatemwa
# kulala
# aye
# dhayawukana
# emibala (colors)
#
# Come to think of it, Dhatemwa kulala is akin to a Vienesse Concerto -- at least as interpreted by Mozart. "Dhatemwa kulala" is analogous to the "Concerto" whereas "aye" is analogous to the "Solo" of the concerto.
#
# “Arco” (played with a bow) and “Pizzicato” (played by plucking the strings) are techniques used primarily with stringed instruments, adding a sense of technique, artistry, and precision to the theme. Let’s craft a musical-inspired framework around these terms:
#
# Concerto
# A piece of music in which one solo instrument is accompanied by an orchestra, symbolizing the lead research and its many collaborative components. so what is our lead research? older living kidney donors? oh yeah!
#
# Subgroups:
# Arco: Teams or projects that follow a continuous, flowing methodology, emphasizing smooth transitions and long-term objectives.
# Pizzicato: Representing initiatives that require precision and distinct, impactful outcomes, akin to the sharp and distinct sound produced by plucking strings.
# Vibrato: Projects that resonate and have a lasting impact, emphasizing depth and richness.
# Sordino: For discreet, background projects, much like the muted tones produced using a mute.
# Tremolo: Fast-paced, high-frequency tasks or projects, akin to the rapid oscillation of a musical note.
# Ritardando: Initiatives that start quickly but gradually slow down, allowing for reflection and recalibration.
# The central theme, Concerto, portrays the amalgamation of various elements to produce a masterpiece, while the subgroups, inspired by specific techniques and musical nuances, capture the varied approaches and paces of research projects. This structure paints a picture of a finely-tuned orchestra, each section playing its role to perfection.

# %% [markdown]
# https://docs.github.com/en/authentication/connecting-to-github-with-ssh/generating-a-new-ssh-key-and-adding-it-to-the-ssh-agent
#
# upgrade
# workflow
#
# ---
#
# It seems like you're encountering an issue related to SSH keys. An SSH key is a secure way to authenticate yourself when connecting to a remote server or machine. To resolve the error message you mentioned, you need to ensure that you are providing a valid OpenSSH public key format.
#
# Here are some steps to create an SSH key pair and obtain the public key in OpenSSH format:
#
# 1. **Generate SSH Key Pair**:
#
# If you haven't generated an SSH key pair yet, you can do so using the `ssh-keygen` command on your local machine:
#
# ```bash
# ssh-keygen -t rsa -b 4096 -C "your_email@example.com"
# ```
#
# This command will generate a new RSA key pair with a 4096-bit key size. Replace "your_email@example.com" with your actual email address.
#
# 2. **Locate the Public Key**:
#
# Once the key pair is generated, you'll find the public key in a file with a `.pub` extension in your home directory. By default, the file name is `id_rsa.pub`, but it might be different if you provided a custom name during key generation.
#
# 3. **Ensure OpenSSH Format**:
#
# Open the public key file using a text editor and verify that it is in OpenSSH public key format. The contents should look something like this:
#
# ```
# ssh-rsa AAAAB3NzaC1yc2EAAAADAQABAAAB...
# ```
#
# If you copied the key from a web page or an email, make sure no extra spaces or characters are present.
#
# 4. **Using the Public Key**:
#
# When connecting to a remote server or service that requires your public key, ensure you copy the entire content of the public key file (usually `id_rsa.pub`) into the appropriate field or file on the server. The exact steps may vary depending on the service or platform you are using.
#
# After following these steps, your key should be recognized as a valid OpenSSH public key, and you should be able to use it for SSH authentication without encountering the "Key is invalid" error.
#
# ---
#
# cd /users/d/.ssh
# cat id_adm16181.pub #add to repo
# cat id_adm16181 #
# ssh-keygen -t ed25519 -C "dhatemwakulala@gmail.com"
# /Users/d/.ssh/id_ed25519 already exists
# Overwrite (y/n)? n
# ssh-keygen -t adm16181 -C "dhatemwakulala@gmail.com"
# Enter file in which to save the key: /Users/d/.ssh/id_adm16181
# Enter passphrase (empty for no passphrase):drum
#
# ```unix
# Your identification has been saved in /Users/d/.ssh/id_adm16181
# Your public key has been saved in /Users/d/.ssh/id_adm16181.pub
# The key fingerprint is:
# SHA256:WwvgZyFEEzKKB3UKNsi/A8fpseP/RVnvUq4/7ZkG/q4 dhatemwakulala@gmail.com
# The key's randomart image is:
# +--[ED25519 256]--+
# |=+. +.=.         |
# |o=.+ + .         |
# |. * . o .  .     |
# | o * . o .o .    |
# |  + + . So.  o   |
# |   *   o.+ .+.   |
# |  . o   .....oo  |
# |   .    .   oo oo|
# |    ....   ..EB* |
# +----[SHA256]-----+
# ```
#
# eval "$(ssh-agent -s)"
# Agent pid 36588
# open ~/.ssh/config #paste stuff
# ssh-add --apple-use-keychain ~/.ssh/id_adm16181.pub
#
# ---
#
# pbcopy < ~/.ssh/id_adm16181.pub #copy contents to clipboard
#
# ---
# git remote -v
# git remote set-url origin git@github.com:dhatemwakulala/kelele.git
# ssh-add ~/.ssh/id_adm16181
# git push
# drum
# git push #success!

# %%
import pandas as pd

# Sample data for demonstration purposes
languages = [
    "English",
    "Spanish",
    "French",
    "German",
    "Latin",
    "Italian",
    "Hindi",
    "Arabic",
    "Hebrew",
    "Swahili",
    "Yoruba",
    "Igbo",
    "Zulu",
    "Xhosa",
    "Russian",
    "Chinese",
    "Japanese",
    "Korean",
    "Turkish",
    "Greek",
    "Thai",
    "Vietnamese",
    "Indonesian",
    "Malay",
    "Tagalog",
    "Bengali",
    "Punjabi",
    "Tamil",
]

# English equivalents of "melody," "harmony," and "rhythm" for each language
melody = [
    "melody",
    "melody",
    "melody",
    "melody",
    "melody",
    "melody",
    "स्वर",
    "نغمة",
    "מֶלוֹדִיָה",
    "melodi",
    "orin",
    "mkpọ",
    "inkanyezi",
    "umculo",
    "мелодия",
    "旋律",
    "メロディ",
    "멜로디",
    "melodi",
    "μελωδία",
    "ทำนองเพลง",
    "giai điệu",
    "điệu nhạc",
    "melodi",
    "awit",
    "ਮੈਲੋਡੀ",
    "இசை",
    "మెలడీ",
]

harmony = [
    "harmony",
    "armonía",
    "harmonie",
    "Harmonie",
    "harmonia",
    "armonia",
    "सामंजस्य",
    "توافق",
    "הַרְמוֹנִיָה",
    "umwiliso",
    "oorin",
    "imeela",
    "ukunqanda",
    "isigubhu",
    "гармония",
    "和谐",
    "harmony",
    "Harmonie",
    "uyum",
    "αρμονία",
    "ความสงบ",
    "hòa âm",
    "keselarasan",
    "harmoni",
    "uskong",
    "ਸ਼ਾਨਦਾਰੀ",
    "இசைப்பொருள்",
    "హార్మోనీ",
]

rhythm = [
    "rhythm",
    "ritmo",
    "rythme",
    "Rhythmus",
    "ritmo",
    "ritmo",
    "ताल",
    "إيقاع",
    "קְצָב",
    "mtindo",
    "irin",
    "ọgbanje",
    "isigubhu",
    "isigubhu",
    "ритм",
    "节奏",
    "リズム",
    "리듬",
    "ritim",
    "ρυθμός",
    "จังหวะ",
    "nhịp điệu",
    "nhịp điệu",
    "iritmo",
    "pandayaw",
    "ਤਾਲ",
    "இசையின் பாட்டின்",
    "రిద్ధం",
]

# Creating the table using pandas
data = {
    "Languages": languages,
    "Melody": melody,
    "Harmony": harmony,
    "Rhythm": rhythm,
}

df = pd.DataFrame(data)

# Displaying the table
print(df)
# Out:
#      Languages      Melody       Harmony            Rhythm
# 0      English      melody       harmony            rhythm
# 1      Spanish      melody       armonía             ritmo
# 2       French      melody      harmonie            rythme
# 3       German      melody      Harmonie          Rhythmus
# 4        Latin      melody      harmonia             ritmo
# 5      Italian      melody       armonia             ritmo
# 6        Hindi        स्वर      सामंजस्य               ताल
# 7       Arabic        نغمة         توافق             إيقاع
# 8       Hebrew  מֶלוֹדִיָה  הַרְמוֹנִיָה             קְצָב
# 9      Swahili      melodi      umwiliso            mtindo
# 10      Yoruba        orin         oorin              irin
# 11        Igbo        mkpọ        imeela           ọgbanje
# 12        Zulu   inkanyezi     ukunqanda          isigubhu
# 13       Xhosa      umculo      isigubhu          isigubhu
# 14     Russian     мелодия      гармония              ритм
# ...

# %% [markdown]
# ```unix
# 01. ssh-keygen -t ed25519 -C "dhatemwakulala@gmail.com"
# 02. /users/d/.ssh/id_adm12345
# 03. ngoma
#
# Your identification has been saved in /users/d/.ssh/id_adm12345
# Your public key has been saved in /users/d/.ssh/id_adm12345.pub
# The key fingerprint is:
# SHA256:9ZG067hcjqW7G+hksoeRZy9NJxY2+I9Q26IMmcev9PM dhatemwakulala@gmail.com
# The key's randomart image is:
# +--[ED25519 256]--+
# |            .    |
# |           . o   |
# |         .. +    |
# |        ..=. o   |
# |       =S+ =o    |
# |      * *.Boo    |
# |      .O=Oo*+    |
# |      .B=o*O.    |
# |      ..ooX*E    |
# +----[SHA256]-----+
#
#
# 04. cat /users/d/.ssh/id_adm12345.pub
# 05. private (or public) github repo
# 06. deploy key on github
# 07. eval "$(ssh-agent -s)"
# 08. Agent pid 42306
# 09. pbcopy < ~/.ssh/id_adm12345.pub
# 10. chmod 600 ~/.ssh/id_adm12345
# 11. chmod 644 ~/.ssh/id_adm12345.pub
# 12. ssh-add ~/.ssh/id_adm12345
# 13. ngoma
# 14. git clone git@github.com:dhatemwakulala/tusirike.git
# 15. &etc
#
# ```

# %% [markdown]
# ```unix
# # fena tusirike
# git clone git@github.com:dhatemwakulala/tusirike.git #different syntax for private repos
# (base) d@Poseidon 1.ontology % ssh-keygen -t ed25519 -C "dhatemwakulala@gmail.com"
# Generating public/private ed25519 key pair.
# Enter file in which to save the key (/Users/d/.ssh/id_ed25519): /Users/d/.ssh/id_adm06180
# Enter passphrase (empty for no passphrase):
# Enter same passphrase again:ngoma
# Your identification has been saved in /Users/d/.ssh/id_adm06180
# Your public key has been saved in /Users/d/.ssh/id_adm06180.pub
# The key fingerprint is:
# SHA256:AoiqRADaJ6hWfHAU6b/O2sdk+XtTYythzFUjmlKcjPA dhatemwakulala@gmail.com
# The key's randomart image is:
# +--[ED25519 256]--+
# |+  ..+o.. + .    |
# |o+..o.  .. = . ..|
# |+.+o+.   E. o . o|
# |+ .o.o   . o   . |
# |oo    o S o o .  |
# |+      o +   = + |
# |.       = . . + o|
# |      o. o . + . |
# |     .o+.  .o o  |
# +----[SHA256]-----+
# (base) d@Poseidon 1.ontology %
#
# eval "$(ssh-agent -s)"
# Agent pid 39375
#
#
#  #change permissions
# pbcopy < ~/.ssh/id_adm06180.pub #copy contents to clipboard
#
# cat /users/d/.ssh/id_adm06180.pub
# ```
